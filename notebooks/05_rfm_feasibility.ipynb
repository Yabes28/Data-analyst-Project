# %% [markdown]
# # RFM Feasibility
#
# **Question:** Is classic RFM segmentation informative for this observed dataset window?
#
# The authoritative assessment is generated by `src/analysis/python/rfm_feasibility.py`. No segmentation is assumed or forced.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
rfm = pd.read_csv(ROOT / 'reports/python-analysis/results/rfm-feasibility.csv')
rfm

# %% [markdown]
# ## Interpretation and limitation
#
# Recency uses a deterministic dataset cutoff. Monetary is Observed Customer Product GMV, not lifetime value. Frequency ties are preserved; no jitter or arbitrary rank is used to manufacture quantile bins.
