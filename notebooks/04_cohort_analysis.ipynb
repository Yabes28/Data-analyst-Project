# %% [markdown]
# # Observed Cohort Analysis
#
# **Question:** What repeat activity is observable after first observed eligible purchase?
#
# Authoritative calculations are generated by `src/analysis/python/cohort.py` and `run_python_analysis.py`. This notebook is a narrative inspection layer. Cohorts are not true acquisition cohorts; censored cells are not zero.

# %%
from pathlib import Path
import pandas as pd
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
summary = pd.read_csv(ROOT / 'reports/python-analysis/results/cohort-summary.csv')
summary.head()

# %% [markdown]
# ## Interpretation and limitation
#
# Use complete-period cohorts for headline comparisons. Month 0 is 100% by construction and is not evidence of repeat behavior. Later unavailable periods remain censored/NULL.
